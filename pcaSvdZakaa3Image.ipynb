# %% [markdown]
# - PCA itu untuk menemukan arah varian dan varian diukur dari titik pusat atau rata rata
# - Memusatkan data dengan menghitung rata-rata setiap kolom pixel x lalu dikurangi setiap elemen dengan nilai rata rata untuk mendapatkan nilai yang terpusat.
# - Hitung matriks kovarians dari matriks x. jadi cari C dari Xc dengan rumusnya (rumus ppt)
# - untuk eigenvektor itu untuk memberi arah dari sumbu baru data dan eigenvalue itu menghasilkan nilai yang penting dari eigenvektor. Semakin besar berarti varian data banyak
# - Urutkan pasangan eigenvektor dan eigenvalue dari terbesar hingga terkecil dan ambil eigenvektor sesuai k yang diinginkan. Misal k=25 berarti ambil 25 teratas
# - Jumlahkan eigenvektor yang mana nantinya jadi sebuah matriks proyeksi
# - Kalikan matriks data terpusat dengan matrik proyeksi untuk representasi gambar
#
# - SVD
# - ....

# %%
import numpy as np
import matplotlib.pyplot as plt

# Fungsi PCA, SVD, Hu Moments manual (dengan komentar rumus)
def pca_manual(img, k):
    X_mean = np.mean(img, axis=0)
    X_terpusat = img - X_mean
    
    # Matriks kovarians (Cov(X) = (X^T X) / (n-1))
    cov = (X_terpusat.T @ X_terpusat) / (X_terpusat.shape[0] - 1)
    
    # Eigenvalue dan eigenvector (Cov X = V Λ V^T)
    eigval, eigvec = np.linalg.eigh(cov)
    idx = np.argsort(eigval)[::-1]# Urutkan menurun
    eigval = eigval[idx][:k] # Ambil k terbesar
    eigvec = eigvec[:, idx][:, :k] # Ambil k eigenvector utama
    
    # PCA (Z = X_terpusat @ V_k)
    fitur_pca = X_terpusat @ eigvec
    
    # Rekonstruksi gambar (X_recon = Z @ V_k^T + mean)
    X_recon = fitur_pca @ eigvec.T + X_mean #(terpusat)
    return eigval, X_recon

def svd_manual(img, k):
    # SVD= X = U S V^T
    AAT = img @ img.T # Untuk U dan S
    ATA = img.T @ img

    # Eigenvalue dan eigenvector (AAT = U Λ U^T, ATA = V Λ V^T)
    eigval_U, U = np.linalg.eigh(AAT)
    eigval_V, V = np.linalg.eigh(ATA)

    eigval_U = np.clip(eigval_U, 0, None)
    eigval_V = np.clip(eigval_V, 0, None)

    # Singular value (S = sqrt(eigenvalue_U), ambil k terbesar)
    S = np.sqrt(np.sort(eigval_U)[::-1])[:k]
    U = U[:, np.argsort(eigval_U)[::-1][:k]]
    V = V[:, np.argsort(eigval_V)[::-1][:k]]

    # gambar SVD (X ≈ U_k S_k V_k^T)
    fitur_svd = U * S
    recon_svd = (U * S) @ V.T
    return S, recon_svd

# Raw moment: m_pq = Σx Σy x^p y^q f(x,y)
def raw_moment(arr, p, q):
    y, x = np.indices(arr.shape)
    return np.sum((x**p) * (y**q) * arr)

# Central moment: μ_pq = Σx Σy (x-x̄)^p (y-ȳ)^q f(x,y)
def central_moment(arr, p, q):
    y, x = np.indices(arr.shape)
    m00 = raw_moment(arr, 0, 0)
    x_bar = raw_moment(arr, 1, 0) / m00
    y_bar = raw_moment(arr, 0, 1) / m00
    return np.sum(((x - x_bar)**p) * ((y - y_bar)**q) * arr)

# 7 invariant moments dari kombinasi momen normalisasi
def hu_moments(arr):
    arr = np.clip(arr, 0, 255)
    m00 = raw_moment(arr, 0, 0)
    m10 = raw_moment(arr, 1, 0)
    m01 = raw_moment(arr, 0, 1)
    x_bar = m10 / m00
    y_bar = m01 / m00

    mu20 = central_moment(arr, 2, 0)
    mu02 = central_moment(arr, 0, 2)
    mu11 = central_moment(arr, 1, 1)
    mu30 = central_moment(arr, 3, 0)
    mu03 = central_moment(arr, 0, 3)
    mu12 = central_moment(arr, 1, 2)
    mu21 = central_moment(arr, 2, 1)

    # Normalisasi momen (η_pq = μ_pq / m00^γ)
    eta20 = mu20 / m00**2
    eta02 = mu02 / m00**2
    eta11 = mu11 / m00**2
    eta30 = mu30 / m00**2.5
    eta03 = mu03 / m00**2.5
    eta12 = mu12 / m00**2.5
    eta21 = mu21 / m00**2.5

    # Rumus Hu Moments (7 invariant moments)
    hu = np.zeros(7)
    hu[0] = eta20 + eta02
    hu[1] = (eta20 - eta02)**2 + 4*eta11**2
    hu[2] = (eta30 - 3*eta12)**2 + (3*eta21 - eta03)**2
    hu[3] = (eta30 + eta12)**2 + (eta21 + eta03)**2
    hu[4] = (eta30 - 3*eta12)*(eta30 + eta12)*((eta30 + eta12)**2 - 3*(eta21 + eta03)**2) + \
            (3*eta21 - eta03)*(eta21 + eta03)*(3*(eta30 + eta12)**2 - (eta21 + eta03)**2)
    hu[5] = (eta20 - eta02)*((eta30 + eta12)**2 - (eta21 + eta03)**2) + 4*eta11*(eta30 + eta12)*(eta21 + eta03)
    hu[6] = (3*eta21 - eta03)*(eta30 + eta12)*((eta30 + eta12)**2 - 3*(eta21 + eta03)**2) - \
            (eta30 - 3*eta12)*(eta21 + eta03)*(3*(eta30 + eta12)**2 - (eta21 + eta03)**2)
    return hu

def load_gray(path):
    img = plt.imread(path)
    if img.ndim == 3:
        img = img.mean(axis=2)
    return img.astype(np.float32)

img_asli = load_gray('img/gregeddd.jpg')
img_vert = load_gray('img/gregeddd-vertical.jpg')
img_mirr = load_gray('img/gregeddd-mirror.jpg')



k = 25 #nilai komponen utama yang disimpan


results = {}
for label, img in zip(['Asli', 'Vertical', 'Mirror'], [img_asli, img_vert, img_mirr]):
    eigval, X_recon = pca_manual(img, k)
    S, recon_svd = svd_manual(img, k)
    hu_ori = hu_moments(img)
    hu_pca = hu_moments(X_recon)
    hu_svd = hu_moments(recon_svd)
    results[label] = {
        'eigval': eigval,
        'S': S,
        'hu_ori': hu_ori,
        'hu_pca': hu_pca,
        'hu_svd': hu_svd,
        'X_recon': X_recon,
        'recon_svd': recon_svd,
        'img': img
    }

for label in ['Asli', 'Vertical', 'Mirror']:
    print(f'\n--------------------------------------- {label} --------------------------------------------')
    print('EIGENVALUE PCA:')
    for i, val in enumerate(results[label]['eigval']):
        print(f'  Komponen {i+1}: {val:.4f}')
    print('SINGULAR VALUE SVD:')
    for i, val in enumerate(results[label]['S']):
        print(f'  Komponen {i+1}: {val:.4f}')
    print('HU MOMENTS:')
    print('  Gambar asli:')
    for i, val in enumerate(results[label]['hu_ori']):
        print(f'    Hu[{i+1}]: {val:.6e}')
    print('  Rekonstruksi PCA:')
    for i, val in enumerate(results[label]['hu_pca']):
        print(f'    Hu[{i+1}]: {val:.6e}')
    print('  Rekonstruksi SVD:')
    for i, val in enumerate(results[label]['hu_svd']):
        print(f'    Hu[{i+1}]: {val:.6e}')
# Out:
# --------------------------------------- Asli --------------------------------------------
# EIGENVALUE PCA:
#   Komponen 1: 85248.0078
#   Komponen 2: 37148.3398
#   Komponen 3: 34008.2070
#   Komponen 4: 21159.3945
#   Komponen 5: 17662.7031
#   Komponen 6: 12566.5732
#   Komponen 7: 10794.9043
#   Komponen 8: 10529.0322
#   Komponen 9: 8634.2305
#   Komponen 10: 5618.7456
#   Komponen 11: 5004.1733
#   Komponen 12: 4283.8027
#   Komponen 13: 4114.9800
#   Komponen 14: 3564.3853
#   Komponen 15: 2849.6692
#   Komponen 16: 2377.5840
#   Komponen 17: 2277.1746
#   Komponen 18: 2043.8964
#   Komponen 19: 2015.2052
#   Komponen 20: 1628.5023
#   Komponen 21: 1539.5751
#   Komponen 22: 1383.4951
#   Komponen 23: 1356.6506
#   Komponen 24: 1215.1969
#   Komponen 25: 1064.1802
# SINGULAR VALUE SVD:
#   Komponen 1: 13576.1943
#   Komponen 2: 4218.7192
#   Komponen 3: 2825.4761
#   Komponen 4: 2184.4722
#   Komponen 5: 2002.5942
#   Komponen 6: 1681.5919
#   Komponen 7: 1583.9954
#   Komponen 8: 1545.4702
#   Komponen 9: 1400.6866
#   Komponen 10: 1284.2198
#   Komponen 11: 1068.8767
#   Komponen 12: 1016.9246
#   Komponen 13: 973.7109
#   Komponen 14: 895.7875
#   Komponen 15: 807.8926
#   Komponen 16: 732.4934
#   Komponen 17: 725.4627
#   Komponen 18: 701.3208
#   Komponen 19: 677.7532
#   Komponen 20: 617.9318
#   Komponen 21: 599.0372
#   Komponen 22: 564.0131
#   Komponen 23: 553.3748
#   Komponen 24: 528.3554
#   Komponen 25: 497.0398
# HU MOMENTS:
#   Gambar asli:
#     Hu[1]: 2.658024e-03
#     Hu[2]: 1.022327e-06
#     Hu[3]: 1.008936e-10
#     Hu[4]: 1.467341e-13
#     Hu[5]: -4.959545e-25
#     Hu[6]: 1.359342e-16
#     Hu[7]: 2.697849e-25
#   Rekonstruksi PCA:
#     Hu[1]: 2.653148e-03
#     Hu[2]: 1.016325e-06
#     Hu[3]: 1.003216e-10
#     Hu[4]: 1.910042e-13
#     Hu[5]: -6.206307e-25
#     Hu[6]: 1.861122e-16
#     Hu[7]: 5.602602e-25
#   Rekonstruksi SVD:
#     Hu[1]: 2.628283e-03
#     Hu[2]: 9.754385e-07
#     Hu[3]: 7.525164e-11
#     Hu[4]: 1.421400e-12
#     Hu[5]: 4.150124e-25
#     Hu[6]: -3.227654e-17
#     Hu[7]: -1.469465e-23
#
# --------------------------------------- Vertical --------------------------------------------
# EIGENVALUE PCA:
#   Komponen 1: 85248.0078
#   Komponen 2: 37148.3398
#   Komponen 3: 34008.2070
#   Komponen 4: 21159.3945
#   Komponen 5: 17662.7031
#   Komponen 6: 12566.5732
#   Komponen 7: 10794.9043
#   Komponen 8: 10529.0322
#   Komponen 9: 8634.2305
#   Komponen 10: 5618.7456
#   Komponen 11: 5004.1733
#   Komponen 12: 4283.8027
#   Komponen 13: 4114.9800
#   Komponen 14: 3564.3853
#   Komponen 15: 2849.6692
#   Komponen 16: 2377.5840
#   Komponen 17: 2277.1746
#   Komponen 18: 2043.8964
#   Komponen 19: 2015.2052
#   Komponen 20: 1628.5023
#   Komponen 21: 1539.5751
#   Komponen 22: 1383.4951
#   Komponen 23: 1356.6506
#   Komponen 24: 1215.1969
#   Komponen 25: 1064.1802
# SINGULAR VALUE SVD:
#   Komponen 1: 13576.1943
#   Komponen 2: 4218.7192
#   Komponen 3: 2825.4761
#   Komponen 4: 2184.4722
#   Komponen 5: 2002.5942
#   Komponen 6: 1681.5919
#   Komponen 7: 1583.9954
#   Komponen 8: 1545.4702
#   Komponen 9: 1400.6866
#   Komponen 10: 1284.2198
#   Komponen 11: 1068.8767
#   Komponen 12: 1016.9246
#   Komponen 13: 973.7109
#   Komponen 14: 895.7875
#   Komponen 15: 807.8926
#   Komponen 16: 732.4934
#   Komponen 17: 725.4627
#   Komponen 18: 701.3208
#   Komponen 19: 677.7532
#   Komponen 20: 617.9318
#   Komponen 21: 599.0372
#   Komponen 22: 564.0131
#   Komponen 23: 553.3748
#   Komponen 24: 528.3554
#   Komponen 25: 497.0398
# HU MOMENTS:
#   Gambar asli:
#     Hu[1]: 2.658024e-03
#     Hu[2]: 1.022327e-06
#     Hu[3]: 1.008936e-10
#     Hu[4]: 1.467341e-13
#     Hu[5]: -4.959545e-25
#     Hu[6]: 1.359342e-16
#     Hu[7]: 2.697849e-25
#   Rekonstruksi PCA:
#     Hu[1]: 2.653148e-03
#     Hu[2]: 1.016325e-06
#     Hu[3]: 1.003216e-10
#     Hu[4]: 1.910042e-13
#     Hu[5]: -6.206307e-25
#     Hu[6]: 1.861122e-16
#     Hu[7]: 5.602602e-25
#   Rekonstruksi SVD:
#     Hu[1]: 2.628283e-03
#     Hu[2]: 9.754385e-07
#     Hu[3]: 7.525164e-11
#     Hu[4]: 1.421400e-12
#     Hu[5]: 4.150124e-25
#     Hu[6]: -3.227654e-17
#     Hu[7]: -1.469465e-23
#
# --------------------------------------- Mirror --------------------------------------------
# EIGENVALUE PCA:
#   Komponen 1: 84578.5469
#   Komponen 2: 36795.0430
#   Komponen 3: 33356.6992
#   Komponen 4: 20846.0137
#   Komponen 5: 17098.9570
#   Komponen 6: 11983.4082
#   Komponen 7: 10267.0791
#   Komponen 8: 10158.6426
#   Komponen 9: 8338.8398
#   Komponen 10: 5384.7988
#   Komponen 11: 4583.5103
#   Komponen 12: 4039.6816
#   Komponen 13: 3785.8181
#   Komponen 14: 3317.4934
#   Komponen 15: 2476.4961
#   Komponen 16: 2173.2769
#   Komponen 17: 2065.5859
#   Komponen 18: 1885.9781
#   Komponen 19: 1834.3141
#   Komponen 20: 1476.1249
#   Komponen 21: 1367.1561
#   Komponen 22: 1244.2080
#   Komponen 23: 1087.1498
#   Komponen 24: 1047.0002
#   Komponen 25: 930.6096
# SINGULAR VALUE SVD:
#   Komponen 1: 13542.3818
#   Komponen 2: 4197.3340
#   Komponen 3: 2802.5005
#   Komponen 4: 2169.5730
#   Komponen 5: 1969.8685
#   Komponen 6: 1642.1858
#   Komponen 7: 1554.5718
#   Komponen 8: 1512.2772
#   Komponen 9: 1374.4844
#   Komponen 10: 1265.8741
#   Komponen 11: 1023.2100
#   Komponen 12: 996.3560
#   Komponen 13: 927.3948
#   Komponen 14: 863.9794
#   Komponen 15: 753.5815
#   Komponen 16: 703.2548
#   Komponen 17: 695.2455
#   Komponen 18: 671.6157
#   Komponen 19: 649.1297
#   Komponen 20: 585.3605
#   Komponen 21: 563.6248
#   Komponen 22: 532.5480
#   Komponen 23: 499.9705
#   Komponen 24: 488.8387
#   Komponen 25: 467.8455
# HU MOMENTS:
#   Gambar asli:
#     Hu[1]: 2.663661e-03
#     Hu[2]: 1.055515e-06
#     Hu[3]: 9.780218e-11
#     Hu[4]: 1.549116e-13
#     Hu[5]: -5.774551e-25
#     Hu[6]: 1.351153e-16
#     Hu[7]: -1.735677e-25
#   Rekonstruksi PCA:
#     Hu[1]: 2.659922e-03
#     Hu[2]: 1.050703e-06
#     Hu[3]: 9.735352e-11
#     Hu[4]: 1.858900e-13
#     Hu[5]: -6.935877e-25
#     Hu[6]: 1.738735e-16
#     Hu[7]: -3.798434e-25
#   Rekonstruksi SVD:
#     Hu[1]: 2.521810e-03
#     Hu[2]: 7.670074e-07
#     Hu[3]: 1.540632e-10
#     Hu[4]: 6.140500e-11
#     Hu[5]: 2.753741e-21
#     Hu[6]: 1.394062e-14
#     Hu[7]: -5.299764e-21

# %%
# Gambar
plt.figure(figsize=(12,6))
for i, label in enumerate(['Asli', 'Vertical', 'Mirror']):
    plt.subplot(3,3,1+i*3)
    plt.imshow(results[label]['img'], cmap='gray')
    plt.title(f'{label} - Asli')
    plt.axis('off')
    plt.subplot(3,3,2+i*3)
    plt.imshow(results[label]['X_recon'], cmap='gray')
    plt.title(f'{label} - PCA')
    plt.axis('off')
    plt.subplot(3,3,3+i*3)
    plt.imshow(results[label]['recon_svd'], cmap='gray')
    plt.title(f'{label} - SVD')
    plt.axis('off')
plt.tight_layout()
plt.show()

#HU
plt.figure(figsize=(14,8))
for label, color in zip(['Asli', 'Vertical', 'Mirror'], ['blue', 'red', 'green']):
    plt.plot(range(1,8), results[label]['hu_ori'], 'o-', label=f'{label} - Asli', color=color)
    plt.plot(range(1,8), results[label]['hu_pca'], 's--', label=f'{label} - PCA', color=color, alpha=0.6)
    plt.plot(range(1,8), results[label]['hu_svd'], '^:', label=f'{label} - SVD', color=color, alpha=0.4)
    for i in range(7):
        plt.text(i+1, results[label]['hu_ori'][i], f"{results[label]['hu_ori'][i]:.1e}", fontsize=8, ha='center', va='bottom', color=color)
        plt.text(i+1, results[label]['hu_pca'][i], f"{results[label]['hu_pca'][i]:.1e}", fontsize=8, ha='center', va='top', color=color)
        plt.text(i+1, results[label]['hu_svd'][i], f"{results[label]['hu_svd'][i]:.1e}", fontsize=8, ha='center', va='top', color=color)
plt.title('Hu Moments Comparison')
plt.xlabel('Index Hu')
plt.ylabel('Nilai')
plt.legend()
plt.tight_layout()
plt.show()

# PCA
plt.figure(figsize=(12,6))
for label, color in zip(['Asli', 'Vertical', 'Mirror'], ['blue', 'red', 'green']):
    plt.plot(range(1, len(results[label]['eigval'])+1), results[label]['eigval'], 'o-', label=f'{label} PCA', color=color)
plt.title('Perbandingan Eigenvalue PCA')
plt.xlabel('Komponen ke-')
plt.ylabel('Nilai Eigenvalue')
plt.legend()
plt.tight_layout()
plt.show()

#SVD
plt.figure(figsize=(12,6))
for label, color in zip(['Asli', 'Vertical', 'Mirror'], ['blue', 'red', 'green']):
    plt.plot(range(1, len(results[label]['S'])+1), results[label]['S'], 's-', label=f'{label} SVD', color=color)
plt.title('Perbandingan Singular Value SVD')
plt.xlabel('Komponen ke-')
plt.ylabel('Nilai Singular Value')
plt.legend()
plt.tight_layout()
plt.show()
